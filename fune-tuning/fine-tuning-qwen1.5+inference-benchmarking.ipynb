# %% [markdown]
# This notebook shows how to:
#
# *   Fine-tune Qwen1.5-7B with QLoRa
# *   Quantize Qwen1.5-7B with GPTQ and AWQ
# *   Do inference with Transformers and vLLM
# *   Benchmark Qwen1.5-7B with optimum-benchmark and the Evaluation Harness.
#
# Each section of this notebook can be run independently.

# %% [markdown]
# # Inference

# %% [markdown]
# With vLLM

# %%
# !pip install vllm
# Out:
# Collecting vllm
#   Downloading vllm-0.3.2-cp310-cp310-manylinux1_x86_64.whl (41.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 20.9 MB/s eta 0:00:00
# Collecting ninja (from vllm)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 41.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from vllm) (5.9.5)
# Collecting ray>=2.9 (from vllm)
#   Downloading ray-2.9.3-cp310-cp310-manylinux2014_x86_64.whl (64.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 MB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from vllm) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vllm) (1.25.2)
# Collecting torch==2.1.2 (from vllm)
#   Downloading torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.5 MB/s eta 0:00:00
# Collecting transformers>=4.38.0 (from vllm)
#   Downloading transformers-4.38.1-py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 100.6 MB/s eta 0:00:00
# Collecting xformers==0.0.23.post1 (from vllm)
#   Downloading xformers-0.0.23.post1-cp310-cp310-manylinux2014_x86_64.whl (213.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 MB 6.8 MB/s eta 0:00:00
# Collecting fastapi (from vllm)
#   Downloading fastapi-0.109.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 14.5 MB/s eta 0:00:00
# Collecting uvicorn[standard] (from vllm)
#   Downloading uvicorn-0.27.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from vllm) (2.6.1)
# Collecting aioprometheus[starlette] (from vllm)
#   Downloading aioprometheus-23.12.0-py3-none-any.whl (31 kB)
# Collecting pynvml==11.5.0 (from vllm)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: triton>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from vllm) (2.1.0)
# Collecting cupy-cuda12x==12.1.0 (from vllm)
#   Downloading cupy_cuda12x-12.1.0-cp310-cp310-manylinux2014_x86_64.whl (83.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 MB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.10/dist-packages (from cupy-cuda12x==12.1.0->vllm) (0.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.2->vllm) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1.2->vllm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 53.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1.2->vllm)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 67.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1.2->vllm)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 92.7 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1.2->vllm)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1.2->vllm)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1.2->vllm)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.8 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1.2->vllm)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1.2->vllm)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 11.8 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1.2->vllm)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.6 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1.2->vllm)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 4.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1.2->vllm)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.7 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2->vllm)
#   Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 88.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->vllm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->vllm) (2.16.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (8.1.7)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (1.0.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (23.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (6.0.1)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray>=2.9->vllm) (2.31.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->vllm) (0.20.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->vllm) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->vllm) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->vllm) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.0->vllm) (4.66.2)
# Collecting orjson (from aioprometheus[starlette]->vllm)
#   Downloading orjson-3.9.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.0/139.0 kB 21.0 MB/s eta 0:00:00
# Collecting quantile-python>=1.1 (from aioprometheus[starlette]->vllm)
#   Downloading quantile-python-1.1.tar.gz (2.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting starlette>=0.14.2 (from aioprometheus[starlette]->vllm)
#   Downloading starlette-0.37.1-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 11.3 MB/s eta 0:00:00
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 11.4 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn[standard]->vllm)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.8 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]->vllm)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 42.4 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->vllm)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->vllm)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 109.3 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vllm)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.7 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]->vllm)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette>=0.14.2->aioprometheus[starlette]->vllm) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.2->vllm) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.9->vllm) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.9->vllm) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.9->vllm) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.9->vllm) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.9->vllm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.9->vllm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.9->vllm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.9->vllm) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.2->vllm) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.14.2->aioprometheus[starlette]->vllm) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette>=0.14.2->aioprometheus[starlette]->vllm) (1.2.0)
# Building wheels for collected packages: quantile-python
#   Building wheel for quantile-python (setup.py) ... done
#   Created wheel for quantile-python: filename=quantile_python-1.1-py3-none-any.whl size=3444 sha256=b7417fe7d27a6602805b64e478c82e7439d809c5c0371b95dfcaac02fefd09f6
#   Stored in directory: /root/.cache/pip/wheels/6d/f4/0a/0e7d01548a005f9f3fa23101f071d248da052f2a9bf2fe11c6
# Successfully built quantile-python
# Installing collected packages: quantile-python, ninja, websockets, uvloop, python-dotenv, pynvml, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, httptools, h11, cupy-cuda12x, watchfiles, uvicorn, starlette, nvidia-cusparse-cu12, nvidia-cudnn-cu12, aioprometheus, nvidia-cusolver-cu12, fastapi, transformers, torch, ray, xformers, vllm
#   Attempting uninstall: cupy-cuda12x
#     Found existing installation: cupy-cuda12x 12.2.0
#     Uninstalling cupy-cuda12x-12.2.0:
#       Successfully uninstalled cupy-cuda12x-12.2.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.37.2
#     Uninstalling transformers-4.37.2:
#       Successfully uninstalled transformers-4.37.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu121
#     Uninstalling torch-2.1.0+cu121:
#       Successfully uninstalled torch-2.1.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# Successfully installed aioprometheus-23.12.0 cupy-cuda12x-12.1.0 fastapi-0.109.2 h11-0.14.0 httptools-0.6.1 ninja-1.11.1.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 orjson-3.9.14 pynvml-11.5.0 python-dotenv-1.0.1 quantile-python-1.1 ray-2.9.3 starlette-0.36.3 torch-2.1.2 transformers-4.38.1 uvicorn-0.27.1 uvloop-0.19.0 vllm-0.3.2 watchfiles-0.21.0 websockets-12.0 xformers-0.0.23.post1

# %% [markdown]
# Without quantization, you need at least 17 GB of GPU VRAM

# %%
import time
from vllm import LLM, SamplingParams

prompts = [
    "The best recipe for pasta is"
]
sampling_params = SamplingParams(temperature=0.7, top_p=0.8, top_k=20, max_tokens=150)

loading_start = time.time()
llm = LLM(model="Qwen/Qwen1.5-7B")
print("--- Loading time: %s seconds ---" % (time.time() - loading_start))

generation_time = time.time()
outputs = llm.generate(prompts, sampling_params)
print("--- Generation time: %s seconds ---" % (time.time() - generation_time))

for output in outputs:
    generated_text = output.outputs[0].text
    print(generated_text)
    print('------')
# Out:
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# INFO 02-23 00:40:52 llm_engine.py:79] Initializing an LLM engine with config: model='Qwen/Qwen1.5-7B', tokenizer='Qwen/Qwen1.5-7B', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=32768, download_dir=None, load_format=auto, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, seed=0)
# tokenizer_config.json:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# INFO 02-23 00:41:01 weight_utils.py:163] Using model weights format ['*.safetensors']
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.54G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# INFO 02-23 00:41:53 llm_engine.py:337] # GPU blocks: 2284, # CPU blocks: 512
# INFO 02-23 00:41:55 model_runner.py:676] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 02-23 00:41:55 model_runner.py:680] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 02-23 00:42:01 model_runner.py:748] Graph capturing finished in 6 secs.
# --- Loading time: 71.13580441474915 seconds ---
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.10s/it]
# --- Generation time: 2.1062939167022705 seconds ---
#  to boil the water first, add the salt, then the pasta. It's a simple and straightforward method. But what if you don't have a pasta pot? You can still make delicious pasta, you just need to know how.
#
# Question: Why is pasta so simple to make but so hard to get right?
#
# Pasta is simple to make because it only requires boiling water and adding salt, but it can be hard to get right because it is a complex dish that requires a lot of trial and error. It is also important to use the right type of pasta and to cook it for the right amount of time. Additionally, the pasta should be drained properly and the sauce should be added just before serving, as the pasta will continue to cook
# ------

# %% [markdown]
# Version with the AWQ quantized model.
# To know how I made this quantized model, have a look at the section "quantization" below.

# %%
import time
from vllm import LLM, SamplingParams

prompts = [
    "The best recipe for pasta is"
]
sampling_params = SamplingParams(temperature=0.7, top_p=0.8, top_k=20, max_tokens=150)

loading_start = time.time()
llm = LLM(model="kaitchup/Qwen1.5-7B-awq-4bit", quantization="awq")
print("--- Loading time: %s seconds ---" % (time.time() - loading_start))

generation_time = time.time()
outputs = llm.generate(prompts, sampling_params)
print("--- Generation time: %s seconds ---" % (time.time() - generation_time))

for output in outputs:
    generated_text = output.outputs[0].text
    print(generated_text)
    print('------')
# Out:
# WARNING 02-17 04:39:38 config.py:180] awq quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# INFO 02-17 04:39:38 llm_engine.py:79] Initializing an LLM engine with config: model='kaitchup/Qwen1.5-7B-awq-4bit', tokenizer='kaitchup/Qwen1.5-7B-awq-4bit', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=32768, download_dir=None, load_format=auto, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=awq, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, seed=0)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# INFO 02-17 04:39:41 weight_utils.py:163] Using model weights format ['*.safetensors']
# INFO 02-17 04:39:46 llm_engine.py:337] # GPU blocks: 3377, # CPU blocks: 512
# INFO 02-17 04:39:48 model_runner.py:666] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 02-17 04:39:48 model_runner.py:670] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 02-17 04:39:55 model_runner.py:738] Graph capturing finished in 7 secs.
# --- Loading time: 18.355043649673462 seconds ---
# Processed prompts: 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]
# --- Generation time: 1.5052404403686523 seconds ---
#  to use good ingredients, to make a simple sauce, and to cook it with a lot of love. The result is a dish that is both comforting and healthy.
# 1. Bring a large pot of salted water to a boil. Add the pasta and cook, stirring occasionally, until al dente, 7 to 8 minutes. Reserve 1 cup of the pasta cooking water, then drain the pasta in a colander and return it to the pot.
# 2. While the pasta cooks, make the sauce. Heat the oil in a large skillet over medium heat. Add the garlic and cook, stirring, until fragrant, about 1 minute. Add the tomatoes, salt, and pepper and cook, stirring, until the tomatoes have softened
# ------

# %% [markdown]
# # Quantization

# %% [markdown]
# Bitsandbytes NF4

# %%
# !pip install --upgrade transformers bitsandbytes accelerate datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.2)
# Collecting transformers
#   Downloading transformers-4.38.1-py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 64.1 MB/s eta 0:00:00
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 16.5 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.27.2-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 31.9 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.17.1-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 44.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.11.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: dill, multiprocess, bitsandbytes, accelerate, transformers, datasets
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.37.2
#     Uninstalling transformers-4.37.2:
#       Successfully uninstalled transformers-4.37.2
# Successfully installed accelerate-0.27.2 bitsandbytes-0.42.0 datasets-2.17.1 dill-0.3.8 multiprocess-0.70.16 transformers-4.38.1

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

model_name = "Qwen/Qwen1.5-7B"
quant_path = 'Qwen1.5-7B-bnb-4bit'
tokenizer = AutoTokenizer.from_pretrained(model_name)
compute_dtype = getattr(torch, "float16")
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config
)


model.save_pretrained("./"+quant_path, safetensors=True)
tokenizer.save_pretrained("./"+quant_path)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/31.7k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# ('./Qwen1.5-7B-bnb-4bit/tokenizer_config.json',
#  './Qwen1.5-7B-bnb-4bit/special_tokens_map.json',
#  './Qwen1.5-7B-bnb-4bit/vocab.json',
#  './Qwen1.5-7B-bnb-4bit/merges.txt',
#  './Qwen1.5-7B-bnb-4bit/added_tokens.json',
#  './Qwen1.5-7B-bnb-4bit/tokenizer.json')

# %% [markdown]
# GPTQ
#
# More details about the GPTQ quantization in this article:
#
# [Quantize and Fine-tune LLMs with GPTQ Using Transformers and TRL](https://kaitchup.substack.com/p/quantize-and-fine-tune-llms-with)

# %%
# !pip install --upgrade transformers auto-gptq accelerate datasets
# !python -m pip install git+https://github.com/huggingface/optimum.git
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.1)
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 70.3 MB/s eta 0:00:00
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.27.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.0.6-py3-none-any.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 89.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.1.0+cu121)
# Collecting peft>=0.5.0 (from auto-gptq)
#   Downloading peft-0.8.2-py3-none-any.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Installing collected packages: rouge, gekko, peft, auto-gptq
# Successfully installed auto-gptq-0.7.0 gekko-1.0.6 peft-0.8.2 rouge-1.0.1
# Collecting git+https://github.com/huggingface/optimum.git
#   Cloning https://github.com/huggingface/optimum.git to /tmp/pip-req-build-vc8jolur
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum.git /tmp/pip-req-build-vc8jolur
#   Resolved https://github.com/huggingface/optimum.git to commit 88f1a9ce0855d896a8ef5e572d9096c01908f437
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting coloredlogs (from optimum==1.18.0.dev0)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (1.12)
# Requirement already satisfied: transformers[sentencepiece]>=4.26.0 in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (4.38.1)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (2.1.0+cu121)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (1.25.2)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (0.20.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from optimum==1.18.0.dev0) (2.17.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (4.9.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum==1.18.0.dev0) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum==1.18.0.dev0) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum==1.18.0.dev0) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum==1.18.0.dev0) (0.4.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum==1.18.0.dev0) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum==1.18.0.dev0) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum==1.18.0.dev0)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum==1.18.0.dev0) (3.9.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum==1.18.0.dev0) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum==1.18.0.dev0) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum==1.18.0.dev0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->optimum==1.18.0.dev0) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum==1.18.0.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum==1.18.0.dev0) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->optimum==1.18.0.dev0) (1.16.0)
# Building wheels for collected packages: optimum
#   Building wheel for optimum (pyproject.toml) ... done
#   Created wheel for optimum: filename=optimum-1.18.0.dev0-py3-none-any.whl size=407155 sha256=e6ec2b2c12d7bb324eb5c57901099292b265eaba15426aaaf868a303deee5ec2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w0p02kkn/wheels/8f/fa/71/cd84bac993f8fa15de35a1c058b91b9394bbc638e56c4327fd
# Successfully built optimum
# Installing collected packages: humanfriendly, coloredlogs, optimum
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 optimum-1.18.0.dev0

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from optimum.gptq import GPTQQuantizer
import torch
model_path = 'Qwen/Qwen1.5-7B'
w = 4 #quantization to 4-bit. Change to 2, 3, or 8 to quantize with another precision

quant_path = 'Qwen1.5-7B-gptq-'+str(w)+'bit'

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=True)
model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype=torch.float16, device_map="auto")
quantizer = GPTQQuantizer(bits=w, dataset="c4", model_seqlen = 2048)
quantized_model = quantizer.quantize_model(model, tokenizer)

quantized_model.save_pretrained("./"+quant_path, safetensors=True)
tokenizer.save_pretrained("./"+quant_path)
# Out:
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/31.7k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/41.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/319M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Quantizing model.layers blocks :   0%|          | 0/32 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# Quantizing layers inside the block:   0%|          | 0/7 [00:00<?, ?it/s]
# WARNING:optimum.gptq.quantizer:Using Exllamav2 backend will reorder the weights offline, thus you will not be able to save the model with the right weights.Setting `disable_exllama=True`. You should only use Exllamav2 backend for inference.
# ('./Qwen1.5-7B-gptq-4bit/tokenizer_config.json',
#  './Qwen1.5-7B-gptq-4bit/special_tokens_map.json',
#  './Qwen1.5-7B-gptq-4bit/vocab.json',
#  './Qwen1.5-7B-gptq-4bit/merges.txt',
#  './Qwen1.5-7B-gptq-4bit/added_tokens.json',
#  './Qwen1.5-7B-gptq-4bit/tokenizer.json')

# %% [markdown]
# AWQ
#
# More details about the AWQ quantization in this article:
#
# [Fast and Small Llama 2 with Activation-Aware Quantization (AWQ)
# ](https://kaitchup.substack.com/p/fast-and-small-llama-2-with-activation)

# %%
# !pip install --upgrade transformers autoawq optimum accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.2)
# Collecting autoawq
#   Downloading autoawq-0.2.1-cp310-cp310-manylinux2014_x86_64.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: optimum in /usr/local/lib/python3.10/dist-packages (1.17.0.dev0)
# Collecting optimum
#   Downloading optimum-1.17.0-py3-none-any.whl (407 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.8/407.8 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.27.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.1.0+cu121)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.9.0)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.1.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.17.0)
# Collecting zstandard (from autoawq)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 34.5 MB/s eta 0:00:00
# Collecting autoawq-kernels (from autoawq)
#   Downloading autoawq_kernels-0.0.5-cp310-cp310-manylinux2014_x86_64.whl (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from optimum) (15.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.1.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers) (3.20.3)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->optimum) (10.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.1->autoawq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->autoawq) (1.16.0)
# Installing collected packages: zstandard, autoawq-kernels, autoawq, optimum
#   Attempting uninstall: optimum
#     Found existing installation: optimum 1.17.0.dev0
#     Uninstalling optimum-1.17.0.dev0:
#       Successfully uninstalled optimum-1.17.0.dev0
# Successfully installed autoawq-0.2.1 autoawq-kernels-0.0.5 optimum-1.17.0 zstandard-0.22.0

# %%
from awq import AutoAWQForCausalLM
from transformers import AutoTokenizer

model_path = 'Qwen/Qwen1.5-7B'
quant_path = 'Qwen1.5-7B-awq-4bit'
quant_config = { "zero_point": True, "q_group_size": 128, "w_bit": 4, "version": "GEMM" }

# Load model and tokenizer
model = AutoAWQForCausalLM.from_pretrained(model_path, safetensors=True)
tokenizer = AutoTokenizer.from_pretrained(model_path, use_fast=True)

# Quantize
model.quantize(tokenizer, quant_config=quant_config)

# Save quantized model with safetensors
model.save_quantized("./"+quant_path, safetensors=True)
tokenizer.save_pretrained("./"+quant_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Generating validation split: 0 examples [00:00, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (57053 > 32768). Running this sequence through the model will result in indexing errors
# AWQ: 100%|██████████| 32/32 [15:10<00:00, 28.44s/it]
# ('./Qwen1.5-7B-awq-4bit/tokenizer_config.json',
#  './Qwen1.5-7B-awq-4bit/special_tokens_map.json',
#  './Qwen1.5-7B-awq-4bit/vocab.json',
#  './Qwen1.5-7B-awq-4bit/merges.txt',
#  './Qwen1.5-7B-awq-4bit/added_tokens.json',
#  './Qwen1.5-7B-awq-4bit/tokenizer.json')

# %% [markdown]
# # Fine-tuning
#
# QLoRA
#
# More details about QLoRA fine-tuning in this article:
#
# [QLoRa: Fine-Tune a Large Language Model on Your GPU](https://kaitchup.substack.com/p/qlora-fine-tune-a-large-language-model-on-your-gpu-27bed5a03e2b)

# %%
# !pip install --upgrade bitsandbytes transformers peft accelerate datasets trl
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting transformers
#   Downloading transformers-4.37.2-py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 107.9 MB/s eta 0:00:00
# Collecting peft
#   Downloading peft-0.8.2-py3-none-any.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 25.9 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.27.2-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 37.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.17.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 55.4 MB/s eta 0:00:00
# Collecting trl
#   Downloading trl-0.7.11-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.11.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.1.0+cu121)
# Collecting pyarrow>=12.0.0 (from datasets)
#   Downloading pyarrow-15.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 43.5 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.7.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2.1.0)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.6.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Installing collected packages: shtab, pyarrow, docstring-parser, dill, multiprocess, bitsandbytes, tyro, accelerate, transformers, datasets, trl, peft
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 10.0.1
#     Uninstalling pyarrow-10.0.1:
#       Successfully uninstalled pyarrow-10.0.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 15.0.0 which is incompatible.
# Successfully installed accelerate-0.27.2 bitsandbytes-0.42.0 datasets-2.17.0 dill-0.3.8 docstring-parser-0.15 multiprocess-0.70.16 peft-0.8.2 pyarrow-15.0.0 shtab-1.6.5 transformers-4.37.2 trl-0.7.11 tyro-0.7.3

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    AutoTokenizer,
    TrainingArguments,
)
from trl import SFTTrainer

model_name = "Qwen/Qwen1.5-7B"
#Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, add_eos_token=True, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.pad_token_id =  tokenizer.eos_token_id
tokenizer.padding_side = 'left'

ds = load_dataset("timdettmers/openassistant-guanaco")
compute_dtype = getattr(torch, "float16")
bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=True,
)
model = AutoModelForCausalLM.from_pretrained(
          model_name, quantization_config=bnb_config, device_map={"": 0}
)
model = prepare_model_for_kbit_training(model)
#Configure the pad token in the model
model.config.pad_token_id = tokenizer.pad_token_id
model.config.use_cache = False # Gradient checkpointing is used by default but not compatible with caching

peft_config = LoraConfig(
        lora_alpha=16,
        lora_dropout=0.05,
        r=16,
        bias="none",
        task_type="CAUSAL_LM",
        target_modules= ['k_proj', 'q_proj', 'v_proj', 'o_proj', "gate_proj", "down_proj", "up_proj"]
)

training_arguments = TrainingArguments(
        output_dir="./drive/Mydrive/results_qlora",
        evaluation_strategy="steps",
        do_eval=True,
        optim="paged_adamw_8bit",
        per_device_train_batch_size=8,
        per_device_eval_batch_size=8,
        log_level="debug",
        save_steps=50,
        logging_steps=50,
        learning_rate=2e-5,
        eval_steps=50,
        max_steps=300,
        warmup_steps=30,
        lr_scheduler_type="linear",
)

trainer = SFTTrainer(
        model=model,
        train_dataset=ds['train'],
        eval_dataset=ds['test'],
        peft_config=peft_config,
        dataset_text_field="text",
        max_seq_length=512,
        tokenizer=tokenizer,
        args=training_arguments,
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading readme:   0%|          | 0.00/395 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data:   0%|          | 0.00/20.9M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/31.7k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# Map:   0%|          | 0/9846 [00:00<?, ? examples/s]
# Map:   0%|          | 0/518 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:294: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# max_steps is given, it will override any value given in num_train_epochs
# Currently training with a batch size of: 8
# ***** Running training *****
#   Num examples = 9,846
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 300
#   Number of trainable parameters = 39,976,960
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 1:14:10, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.369400</td>
#       <td>1.489497</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.270000</td>
#       <td>1.446679</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.243200</td>
#       <td>1.435053</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.232600</td>
#       <td>1.431196</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.253700</td>
#       <td>1.429125</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.234800</td>
#       <td>1.429620</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./drive/Mydrive/results_qlora/tmp-checkpoint-50
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen1.5-7B/snapshots/e52fa2ef47411cc8bc9f752d1d8d9072b37742e7/config.json
# Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151643,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "rms_norm_eps": 1e-06,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.37.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# tokenizer config file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-50/tokenizer_config.json
# Special tokens file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-50/special_tokens_map.json
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./drive/Mydrive/results_qlora/tmp-checkpoint-100
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen1.5-7B/snapshots/e52fa2ef47411cc8bc9f752d1d8d9072b37742e7/config.json
# Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151643,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "rms_norm_eps": 1e-06,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.37.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# tokenizer config file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-100/tokenizer_config.json
# Special tokens file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-100/special_tokens_map.json
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./drive/Mydrive/results_qlora/tmp-checkpoint-150
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen1.5-7B/snapshots/e52fa2ef47411cc8bc9f752d1d8d9072b37742e7/config.json
# Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151643,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "rms_norm_eps": 1e-06,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.37.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# tokenizer config file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-150/tokenizer_config.json
# Special tokens file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-150/special_tokens_map.json
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./drive/Mydrive/results_qlora/tmp-checkpoint-200
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen1.5-7B/snapshots/e52fa2ef47411cc8bc9f752d1d8d9072b37742e7/config.json
# Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151643,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "rms_norm_eps": 1e-06,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.37.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# tokenizer config file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-200/tokenizer_config.json
# Special tokens file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-200/special_tokens_map.json
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./drive/Mydrive/results_qlora/tmp-checkpoint-250
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen1.5-7B/snapshots/e52fa2ef47411cc8bc9f752d1d8d9072b37742e7/config.json
# Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151643,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "rms_norm_eps": 1e-06,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.37.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# tokenizer config file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-250/tokenizer_config.json
# Special tokens file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-250/special_tokens_map.json
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# ***** Running Evaluation *****
#   Num examples = 518
#   Batch size = 8
# Saving model checkpoint to ./drive/Mydrive/results_qlora/tmp-checkpoint-300
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen1.5-7B/snapshots/e52fa2ef47411cc8bc9f752d1d8d9072b37742e7/config.json
# Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151643,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen2",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 32,
#   "rms_norm_eps": 1e-06,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.37.2",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# tokenizer config file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-300/tokenizer_config.json
# Special tokens file saved in ./drive/Mydrive/results_qlora/tmp-checkpoint-300/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=300, training_loss=1.2672652435302734, metrics={'train_runtime': 4462.5801, 'train_samples_per_second': 0.538, 'train_steps_per_second': 0.067, 'total_flos': 5.160105818947584e+16, 'train_loss': 1.2672652435302734, 'epoch': 0.24})

# %% [markdown]
# # Benchmarking

# %% [markdown]
# With optimum-benchmark: Memory-Efficiency and Inference Speed
#
# More details about using optimum-benchmark in this article:
#
# [Optimum-Benchmark: How Fast and Memory-Efficient Is Your LLM?](https://kaitchup.substack.com/p/optimum-benchmark-how-fast-and-memory)

# %%
# !pip install optimum
# !python -m pip install git+https://github.com/huggingface/optimum-benchmark.git
# !pip install bitsandbytes
# !pip install auto-gptq
# !pip install autoawq
# !pip install --upgrade transformers
# Out:
# Collecting optimum
#   Downloading optimum-1.17.0-py3-none-any.whl (407 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.8/407.8 kB 2.9 MB/s eta 0:00:00
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Requirement already satisfied: transformers[sentencepiece]>=4.26.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (4.35.2)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from optimum) (2.1.0+cu121)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.25.2)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (0.20.3)
# Collecting datasets (from optimum)
#   Downloading datasets-2.17.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.9.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->optimum) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.4.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]>=4.26.0->optimum) (3.20.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.7 MB/s eta 0:00:00
# Collecting pyarrow>=12.0.0 (from datasets->optimum)
#   Downloading pyarrow-15.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 33.1 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->optimum)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.4.1)
# Collecting multiprocess (from datasets->optimum)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum) (3.9.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->optimum) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->optimum) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->optimum) (1.16.0)
# Installing collected packages: pyarrow, humanfriendly, dill, multiprocess, coloredlogs, datasets, optimum
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 10.0.1
#     Uninstalling pyarrow-10.0.1:
#       Successfully uninstalled pyarrow-10.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 15.0.0 which is incompatible.
# Successfully installed coloredlogs-15.0.1 datasets-2.17.0 dill-0.3.8 humanfriendly-10.0 multiprocess-0.70.16 optimum-1.17.0 pyarrow-15.0.0
# Collecting git+https://github.com/huggingface/optimum-benchmark.git
#   Cloning https://github.com/huggingface/optimum-benchmark.git to /tmp/pip-req-build-ajrewvgj
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum-benchmark.git /tmp/pip-req-build-ajrewvgj
#   Resolved https://github.com/huggingface/optimum-benchmark.git to commit ccf225a56dc7f89793ea20a7ca2423721dc85c9e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyrsmi@ git+https://github.com/RadeonOpenCompute/pyrsmi.git (from optimum-benchmark==0.0.2)
#   Cloning https://github.com/RadeonOpenCompute/pyrsmi.git to /tmp/pip-install-dn0zl4yu/pyrsmi_8a0d48d7699642998feba2cfe124a66f
#   Running command git clone --filter=blob:none --quiet https://github.com/RadeonOpenCompute/pyrsmi.git /tmp/pip-install-dn0zl4yu/pyrsmi_8a0d48d7699642998feba2cfe124a66f
#   Resolved https://github.com/RadeonOpenCompute/pyrsmi.git to commit 931720d1b120cf3120beea578af632f2f40fd9ff
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.0.2) (4.35.2)
# Collecting accelerate (from optimum-benchmark==0.0.2)
#   Downloading accelerate-0.27.2-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.0.2) (2.17.0)
# Collecting hydra-colorlog (from optimum-benchmark==0.0.2)
#   Downloading hydra_colorlog-1.2.0-py3-none-any.whl (3.6 kB)
# Collecting hydra-core (from optimum-benchmark==0.0.2)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 12.5 MB/s eta 0:00:00
# Collecting omegaconf (from optimum-benchmark==0.0.2)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.0.2) (5.9.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.0.2) (1.5.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.0.2) (13.7.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.0.2) (0.9.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from optimum-benchmark==0.0.2) (3.7.1)
# Collecting flatten-dict (from optimum-benchmark==0.0.2)
#   Downloading flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Collecting py3nvml (from optimum-benchmark==0.0.2)
#   Downloading py3nvml-0.2.7-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.0.2) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.0.2) (23.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.0.2) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.0.2) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.0.2) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate->optimum-benchmark==0.0.2) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.0.2) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.0.2) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.0.2) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.0.2) (0.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.0.2) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.0.2) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.0.2) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.0.2) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.0.2) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum-benchmark==0.0.2) (3.9.3)
# Requirement already satisfied: six<2.0,>=1.12 in /usr/local/lib/python3.10/dist-packages (from flatten-dict->optimum-benchmark==0.0.2) (1.16.0)
# Collecting colorlog (from hydra-colorlog->optimum-benchmark==0.0.2)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core->optimum-benchmark==0.0.2)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optimum-benchmark==0.0.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optimum-benchmark==0.0.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optimum-benchmark==0.0.2) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optimum-benchmark==0.0.2) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optimum-benchmark==0.0.2) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optimum-benchmark==0.0.2) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optimum-benchmark==0.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->optimum-benchmark==0.0.2) (2023.4)
# Collecting xmltodict (from py3nvml->optimum-benchmark==0.0.2)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->optimum-benchmark==0.0.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->optimum-benchmark==0.0.2) (2.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->optimum-benchmark==0.0.2) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->optimum-benchmark==0.0.2) (0.15.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.0.2) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.0.2) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.0.2) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.0.2) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.0.2) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum-benchmark==0.0.2) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate->optimum-benchmark==0.0.2) (4.9.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->optimum-benchmark==0.0.2) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->optimum-benchmark==0.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->optimum-benchmark==0.0.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->optimum-benchmark==0.0.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->optimum-benchmark==0.0.2) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.0.2) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.0.2) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.0.2) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->optimum-benchmark==0.0.2) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate->optimum-benchmark==0.0.2) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate->optimum-benchmark==0.0.2) (1.3.0)
# Building wheels for collected packages: optimum-benchmark, antlr4-python3-runtime, pyrsmi
#   Building wheel for optimum-benchmark (pyproject.toml) ... done
#   Created wheel for optimum-benchmark: filename=optimum_benchmark-0.0.2-py3-none-any.whl size=82380 sha256=400df46937a1141a655ed5d188d36186221a4a96767d2dee394e50a2fd46797f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gjgmdpsq/wheels/48/c5/52/c5e1295ae5e4a012df46fd1e0fce40ca8547c6772c738bbcef
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=ec61c1890d61782b086d52f89d14dabd67c5aa36ff046fcc102f456fc0f52da4
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for pyrsmi (setup.py) ... done
#   Created wheel for pyrsmi: filename=pyrsmi-1.0.2-py2.py3-none-any.whl size=8456 sha256=b32084e823149e8d6b7eb8f323785cfba952df7b89e57db33b762aeb1d11ad8e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gjgmdpsq/wheels/13/c5/a0/e6174d0cd8adf5c8bab06ac38e4aa9fadb904417f321401ad8
# Successfully built optimum-benchmark antlr4-python3-runtime pyrsmi
# Installing collected packages: antlr4-python3-runtime, xmltodict, pyrsmi, omegaconf, flatten-dict, colorlog, py3nvml, hydra-core, hydra-colorlog, accelerate, optimum-benchmark
# Successfully installed accelerate-0.27.2 antlr4-python3-runtime-4.9.3 colorlog-6.8.2 flatten-dict-0.4.2 hydra-colorlog-1.2.0 hydra-core-1.3.2 omegaconf-2.3.0 optimum-benchmark-0.0.2 py3nvml-0.2.7 pyrsmi-1.0.2 xmltodict-0.13.0
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->bitsandbytes) (1.25.2)
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.42.0
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 45.7 MB/s eta 0:00:00
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.27.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.17.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.25.2)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.0.6-py3-none-any.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 49.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.1.0+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.4.2)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.35.2)
# Collecting peft>=0.5.0 (from auto-gptq)
#   Downloading peft-0.8.2-py3-none-any.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.66.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (0.15.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.9.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.31.0->auto-gptq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Installing collected packages: rouge, gekko, peft, auto-gptq
# Successfully installed auto-gptq-0.7.0 gekko-1.0.6 peft-0.8.2 rouge-1.0.1
# Collecting autoawq
#   Downloading autoawq-0.2.2-cp310-cp310-manylinux2014_x86_64.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.8/76.8 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.1.0+cu121)
# Requirement already satisfied: transformers>=4.35.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.35.2)
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.15.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.9.0)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.1.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.27.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.17.0)
# Collecting zstandard (from autoawq)
#   Downloading zstandard-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 27.4 MB/s eta 0:00:00
# Collecting autoawq-kernels (from autoawq)
#   Downloading autoawq_kernels-0.0.5-cp310-cp310-manylinux2014_x86_64.whl (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 43.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.12.1->autoawq) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.1->autoawq) (2023.6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.35.0->autoawq) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->autoawq) (5.9.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->autoawq) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->autoawq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.35.0->autoawq) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.1->autoawq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->autoawq) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.1->autoawq) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->autoawq) (1.16.0)
# Installing collected packages: zstandard, autoawq-kernels, autoawq
# Successfully installed autoawq-0.2.2 autoawq-kernels-0.0.5 zstandard-0.22.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting transformers
#   Downloading transformers-4.37.2-py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# Successfully installed transformers-4.37.2

# %% [markdown]
# Benchmarking Qwen1.5 7B fp16

# %%
import os
YAML_DEFAULT="""
defaults:
  - backend: pytorch # default backend
  - benchmark: inference # we will monitor the inference
  - launcher: process
  - experiment # inheriting from experiment config
  - _self_ # for hydra 1.1 compatibility
  - override hydra/job_logging: colorlog # colorful logging
  - override hydra/hydra_logging: colorlog # colorful logging

hydra:
  run:
    dir: experiments/${experiment_name} #The results will be reported in this directory. Note that "experiment_name" refers to the configuration field name "experiment_name" below
  sweep:
    dir: experiments/${experiment_name}
  job:
    chdir: true
    env_set: #These are environment variable that you may want to set before running the benchmark
      CUDA_VISIBLE_DEVICES: 0
      CUDA_DEVICE_ORDER: PCI_BUS_ID

experiment_name: Qwen1.5-7B-fp16
model: Qwen/Qwen1.5-7B #The model that we want to evaluate. It can be from the Hugging Face Hub or local directory
device: cuda #Which device to use for the benchmark. We will use CUDA, i.e., the GPU

backend:
  torch_dtype: float16 #The model will be loaded with fp16

benchmark:
  memory: true #We will monitor the memory usage
  warmup_runs: 10 #Before the monitoring starts, the inference will be run 10 times for warming up

  new_tokens: 1000 #Inference will generate 1000 tokens
  input_shapes:
    sequence_length: 512 #Prompt will have 512 tokens
    batch_size: 4
"""

with open("Qwen1.5-7B-fp16.yaml", 'w') as f:
  f.write(YAML_DEFAULT)
os.system("optimum-benchmark --config-dir ./ --config-name Qwen1.5-7B-fp16")
# Out:
# 0

# %%
# !cat experiments/Qwen1.5-7B-fp16/benchmark_report.json
# Out:
# {
#     "batch_size": 4,
#     "sequence_length": 512,
#     "num_new_tokens": 1000,
#     "num_return_sequences": 1,
#     "prefill": {
#         "memory": {
#             "max_vram_used(MB)": 20511,
#             "max_memory_reserved(MB)": 19501,
#             "max_memory_allocated(MB)": 18949
#         },
#         "latency": {
#             "list[s]": [
#                 0.192934482,
#                 0.194949987,
#                 0.195894077,
#                 0.19556984,
#                 0.195216664,
#                 0.195924599,
#                 0.196097198,
#                 0.194839468,
#                 0.195526616,
#                 0.196561958,
#                 0.195556153,
#                 0.196075542,
#                 0.196143761,
#                 0.196234932,
#                 0.195558996,
#                 0.19638102,
#                 0.196230546,
#                 0.195916014,
#                 0.19560153,
#                 0.197120475,
#                 0.195986556,
#                 0.19717193,
#                 0.19626747,
#                 0.196125231,
#                 0.19570307,
#                 0.195735442,
#                 0.196100431,
#                 0.195573058,
#                 0.195745505,
#                 0.197240972,
#                 0.197404061,
#                 0.196224727,
#                 0.195687261,
#                 0.197112352,
#                 0.197407336,
#                 0.1960012,
#                 0.195673566,
#                 0.197272804,
#                 0.197514018,
#                 0.196334172,
#                 0.196300678,
#                 0.1975306,
#                 0.197210155,
#                 0.195706284,
#                 0.196309462,
#                 0.196716952,
#                 0.195939359,
#                 0.196720384,
#                 0.196855907,
#                 0.196870323,
#                 0.196541182
#             ],
#             "mean(s)": 0.19618267266666667,
#             "stdev(s)": 0.0008171410646483672
#         },
#         "throughput": {
#             "list[tokens/s]": [
#                 10615.002454563824,
#                 10505.258458929777,
#                 10454.629518992553,
#                 10471.962343477911,
#                 10490.907681938463,
#                 10453.000850597631,
#                 10443.800425949992,
#                 10511.217367930814,
#                 10474.277322940014,
#                 10419.10663099927,
#                 10472.69527745312,
#                 10444.953914751897,
#                 10441.321149134079,
#                 10436.470097994581,
#                 10472.543027373693,
#                 10428.706399426992,
#                 10436.703366253692,
#                 10453.458898974946,
#                 10470.265748943784,
#                 10389.585353829936,
#                 10449.696355703092,
#                 10386.87403425021,
#                 10434.73989856801,
#                 10442.307649850518,
#                 10464.83328033638,
#                 10463.102538169862,
#                 10443.628244753832,
#                 10471.790035619324,
#                 10462.564644843314,
#                 10383.238224966768,
#                 10374.659921509923,
#                 10437.012864336919,
#                 10465.678703530937,
#                 10390.013508641001,
#                 10374.487805255627,
#                 10448.915618883966,
#                 10466.411186066902,
#                 10381.562782470512,
#                 10368.884298632413,
#                 10431.194830413933,
#                 10432.974663490464,
#                 10368.013867218548,
#                 10384.860759325502,
#                 10464.66142088723,
#                 10432.507832964262,
#                 10410.897379093185,
#                 10452.213432013932,
#                 10410.715749721188,
#                 10403.548621987757,
#                 10402.786813124698,
#                 10420.20801523418
#             ],
#             "mean[tokens/s]": 10439.428456320027,
#             "stdev[tokens/s]": 43.66017785744388
#         }
#     },
#     "decode": {
#         "memory": {
#             "max_vram_used(MB)": 42934,
#             "max_memory_reserved(MB)": 41924,
#             "max_memory_allocated(MB)": 24712
#         },
#         "latency": {
#             "list[s]": [
#                 33.56132591233333
#             ],
#             "mean(s)": 33.56132591233333,
#             "stdev(s)": 0.0
#         },
#         "throughput": {
#             "list[tokens/s]": [
#                 119.1848024851144
#             ],
#             "mean[tokens/s]": 119.1848024851144,
#             "stdev[tokens/s]": 0.0
#         }
#     }
# }

# %% [markdown]
# Benchmarking with 4-bit GPTQ

# %%
import os
YAML_DEFAULT="""
defaults:
  - backend: pytorch # default backend
  - benchmark: inference # we will monitor the inference
  - launcher: process
  - experiment # inheriting from experiment config
  - _self_ # for hydra 1.1 compatibility
  - override hydra/job_logging: colorlog # colorful logging
  - override hydra/hydra_logging: colorlog # colorful logging

hydra:
  run:
    dir: experiments/${experiment_name} #The results will be reported in this directory. Note that "experiment_name" refers to the configuration field name "experiment_name" below
  sweep:
    dir: experiments/${experiment_name}
  job:
    chdir: true
    env_set: #These are environment variable that you may want to set before running the benchmark
      CUDA_VISIBLE_DEVICES: 0
      CUDA_DEVICE_ORDER: PCI_BUS_ID

experiment_name: Qwen1.5-7B-gptq-4bit
model: kaitchup/Qwen1.5-7B-gptq-4bit #The model that we want to evaluate. It can be from the Hugging Face Hub or local directory
device: cuda #Which device to use for the benchmark. We will use CUDA, i.e., the GPU

backend:
  torch_dtype: float16 #The model will be loaded with fp16

benchmark:
  memory: true #We will monitor the memory usage
  warmup_runs: 10 #Before the monitoring starts, the inference will be run 10 times for warming up

  new_tokens: 1000 #Inference will generate 1000 tokens
  input_shapes:
    sequence_length: 512 #Prompt will have 512 tokens
    batch_size: 4
"""

with open("Qwen1.5-7B-gptq-4bit.yaml", 'w') as f:
  f.write(YAML_DEFAULT)
os.system("optimum-benchmark --config-dir ./ --config-name Qwen1.5-7B-gptq-4bit")
# Out:
# 0

# %%
# !cat experiments/Qwen1.5-7B-gptq-4bit/benchmark_report.json
# Out:
# {
#     "batch_size": 4,
#     "sequence_length": 512,
#     "num_new_tokens": 1000,
#     "num_return_sequences": 1,
#     "prefill": {
#         "memory": {
#             "max_vram_used(MB)": 11434,
#             "max_memory_reserved(MB)": 10424,
#             "max_memory_allocated(MB)": 9418
#         },
#         "latency": {
#             "list[s]": [
#                 0.340050463,
#                 0.340974996,
#                 0.340027008,
#                 0.340453168,
#                 0.340192991,
#                 0.339539135,
#                 0.339419286,
#                 0.339408833,
#                 0.340415142,
#                 0.340898065,
#                 0.341128107,
#                 0.340863328,
#                 0.340189869,
#                 0.339947456,
#                 0.339436328,
#                 0.339495412,
#                 0.339523525,
#                 0.340904062,
#                 0.340851158,
#                 0.341105999,
#                 0.340976774,
#                 0.341066036,
#                 0.340194348,
#                 0.340187203,
#                 0.339722811,
#                 0.339430896,
#                 0.340000343,
#                 0.340390196,
#                 0.340977223,
#                 0.34109219
#             ],
#             "mean(s)": 0.3402954117,
#             "stdev(s)": 0.0006142485875288464
#         },
#         "throughput": {
#             "list[tokens/s]": [
#                 6022.635528656815,
#                 6006.305518073824,
#                 6023.050968939502,
#                 6015.511654748357,
#                 6020.112272095576,
#                 6031.705299596761,
#                 6033.835095628597,
#                 6034.0209236687715,
#                 6016.183616180035,
#                 6007.66097044288,
#                 6003.609664447849,
#                 6008.273204443982,
#                 6020.167520038641,
#                 6024.460438968545,
#                 6033.532156287055,
#                 6032.482112011576,
#                 6031.9826144594845,
#                 6007.555286918229,
#                 6008.48772824178,
#                 6003.998774586195,
#                 6006.27419860568,
#                 6004.702268272763,
#                 6020.088258491584,
#                 6020.214699257808,
#                 6028.444171798637,
#                 6033.6287124552155,
#                 6023.5233350926355,
#                 6016.6245211128235,
#                 6006.266289522805,
#                 6004.241844411624
#             ],
#             "mean[tokens/s]": 6018.319321581867,
#             "stdev[tokens/s]": 10.864890709342157
#         }
#     },
#     "decode": {
#         "memory": {
#             "max_vram_used(MB)": 20662,
#             "max_memory_reserved(MB)": 19652,
#             "max_memory_allocated(MB)": 15344
#         },
#         "latency": {
#             "list[s]": [
#                 170.9002903793
#             ],
#             "mean(s)": 170.9002903793,
#             "stdev(s)": 0.0
#         },
#         "throughput": {
#             "list[tokens/s]": [
#                 23.405460523924848
#             ],
#             "mean[tokens/s]": 23.405460523924848,
#             "stdev[tokens/s]": 0.0
#         }
#     }
# }

# %% [markdown]
# Benchmarking with 4-bit AWQ

# %%
import os
YAML_DEFAULT="""
defaults:
  - backend: pytorch # default backend
  - benchmark: inference # we will monitor the inference
  - launcher: process
  - experiment # inheriting from experiment config
  - _self_ # for hydra 1.1 compatibility
  - override hydra/job_logging: colorlog # colorful logging
  - override hydra/hydra_logging: colorlog # colorful logging

hydra:
  run:
    dir: experiments/${experiment_name} #The results will be reported in this directory. Note that "experiment_name" refers to the configuration field name "experiment_name" below
  sweep:
    dir: experiments/${experiment_name}
  job:
    chdir: true
    env_set: #These are environment variable that you may want to set before running the benchmark
      CUDA_VISIBLE_DEVICES: 0
      CUDA_DEVICE_ORDER: PCI_BUS_ID

experiment_name: Qwen1.5-7B-awq-4bit
model: kaitchup/Qwen1.5-7B-awq-4bit #The model that we want to evaluate. It can be from the Hugging Face Hub or local directory
device: cuda #Which device to use for the benchmark. We will use CUDA, i.e., the GPU

backend:
  torch_dtype: float16 #The model will be loaded with fp16

benchmark:
  memory: true #We will monitor the memory usage
  warmup_runs: 10 #Before the monitoring starts, the inference will be run 10 times for warming up

  new_tokens: 1000 #Inference will generate 1000 tokens
  input_shapes:
    sequence_length: 512 #Prompt will have 512 tokens
    batch_size: 4
"""

with open("Qwen1.5-7B-awq-4bit.yaml", 'w') as f:
  f.write(YAML_DEFAULT)
os.system("optimum-benchmark --config-dir ./ --config-name Qwen1.5-7B-awq-4bit")
# Out:
# 0

# %%
# !cat experiments/Qwen1.5-7B-awq-4bit/benchmark_report.json
# Out:
# {
#     "batch_size": 4,
#     "sequence_length": 512,
#     "num_new_tokens": 1000,
#     "num_return_sequences": 1,
#     "prefill": {
#         "memory": {
#             "max_vram_used(MB)": 11642,
#             "max_memory_reserved(MB)": 10632,
#             "max_memory_allocated(MB)": 9412
#         },
#         "latency": {
#             "list[s]": [
#                 0.468850611,
#                 0.467203082,
#                 0.470352865,
#                 0.468097367,
#                 0.468764615,
#                 0.467559894,
#                 0.469575453,
#                 0.467329432,
#                 0.466830243,
#                 0.466693559,
#                 0.467303087,
#                 0.475011398,
#                 0.466497257,
#                 0.467188389,
#                 0.467027904,
#                 0.466514316,
#                 0.466937372,
#                 0.468115238,
#                 0.46681191,
#                 0.467071308,
#                 0.466831776,
#                 0.466269733
#             ],
#             "mean(s)": 0.4678562185909091,
#             "stdev(s)": 0.0019114199157202352
#         },
#         "throughput": {
#             "list[tokens/s]": [
#                 4368.1291054134945,
#                 4383.5327267811135,
#                 4354.177793729395,
#                 4375.158128159264,
#                 4368.9304492405,
#                 4380.1874931556895,
#                 4361.386411738179,
#                 4382.347568470715,
#                 4387.033682391481,
#                 4388.318545446221,
#                 4382.594630709127,
#                 4311.47549011024,
#                 4390.165149459818,
#                 4383.670588183218,
#                 4385.176950797356,
#                 4390.00461456364,
#                 4386.027169399497,
#                 4374.991099947915,
#                 4387.205973386583,
#                 4384.769445097236,
#                 4387.0192760828695,
#                 4392.307402891192
#             ],
#             "mean[tokens/s]": 4377.48225887067,
#             "stdev[tokens/s]": 17.701569391303895
#         }
#     },
#     "decode": {
#         "memory": {
#             "max_vram_used(MB)": 18907,
#             "max_memory_reserved(MB)": 17897,
#             "max_memory_allocated(MB)": 15517
#         },
#         "latency": {
#             "list[s]": [
#                 302.3254096244091
#             ],
#             "mean(s)": 302.3254096244091,
#             "stdev(s)": 0.0
#         },
#         "throughput": {
#             "list[tokens/s]": [
#                 13.230776748039007
#             ],
#             "mean[tokens/s]": 13.230776748039007,
#             "stdev[tokens/s]": 0.0
#         }
#     }
# }

# %% [markdown]
# With Evaluation Harness
#
#
# More details about using the Evaluation Harness in this article:
#
# [Behind the OpenLLM Leaderboard: The Evaluation Harness](https://kaitchup.substack.com/p/behind-the-openllm-leaderboard-the)

# %%
# !pip install git+https://github.com/EleutherAI/lm-evaluation-harness.git
# !pip install bitsandbytes
# !pip install --upgrade transformers
# !pip install auto-gptq optimum autoawq
# Out:
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness.git
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness.git to /tmp/pip-req-build-y9jbprev
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/lm-evaluation-harness.git /tmp/pip-req-build-y9jbprev
#   Resolved https://github.com/EleutherAI/lm-evaluation-harness.git to commit f3b7917091afba325af3980a35d8a6dcba03dc3f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (0.27.2)
# Collecting evaluate (from lm_eval==0.4.1)
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (2.17.0)
# Collecting jsonlines (from lm_eval==0.4.1)
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (2.9.0)
# Requirement already satisfied: peft>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (0.8.2)
# Collecting pybind11>=2.6.2 (from lm_eval==0.4.1)
#   Downloading pybind11-2.11.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 4.8 MB/s eta 0:00:00
# Collecting pytablewriter (from lm_eval==0.4.1)
#   Downloading pytablewriter-1.2.0-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 13.3 MB/s eta 0:00:00
# Collecting rouge-score>=0.0.4 (from lm_eval==0.4.1)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm_eval==0.4.1)
#   Downloading sacrebleu-2.4.0-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (1.2.2)
# Collecting sqlitedict (from lm_eval==0.4.1)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (2.1.0+cu121)
# Collecting tqdm-multiprocess (from lm_eval==0.4.1)
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (4.37.2)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.1) (0.22.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->lm_eval==0.4.1) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.0->lm_eval==0.4.1) (3.9.3)
# Collecting responses<0.19 (from evaluate->lm_eval==0.4.1)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.1) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.1) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.1) (1.16.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm_eval==0.4.1)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.1) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.1) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm_eval==0.4.1)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.1) (4.9.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.1) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.1) (3.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.1) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.1) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.1) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.1) (2.1.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm_eval==0.4.1) (0.15.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm_eval==0.4.1) (23.2.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.1) (67.7.2)
# Collecting DataProperty<2,>=1.0.1 (from pytablewriter->lm_eval==0.4.1)
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm_eval==0.4.1)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm_eval==0.4.1)
#   Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm_eval==0.4.1)
#   Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm_eval==0.4.1)
#   Downloading tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.3.2 (from pytablewriter->lm_eval==0.4.1)
#   Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval==0.4.1) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval==0.4.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval==0.4.1) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval==0.4.1) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.0->lm_eval==0.4.1) (4.0.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.1) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.14.0->lm_eval==0.4.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.14.0->lm_eval==0.4.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.14.0->lm_eval==0.4.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.14.0->lm_eval==0.4.1) (2024.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.1) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.1) (2023.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->lm_eval==0.4.1) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==0.4.1) (8.1.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8->lm_eval==0.4.1) (1.3.0)
# Building wheels for collected packages: lm_eval, rouge-score, sqlitedict
#   Building wheel for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.1-py3-none-any.whl size=1128138 sha256=4faaed5f5c7ae6bce587e3ddd349219562e1fd766a6e8211c5e7d9c7558051e7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vr3z9il8/wheels/ff/d5/f4/949f2b285369fc332f8dbba43f220ebd88387ee2f2c0c1174f
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=33d460101a932befdd17dd49a87aa44fcf4a4a1fd866b0d025982403de411934
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=d8ca77fe240eb856e54c0b5fd4032400adfdca6788c17cc208e8cfaffdc50c85
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built lm_eval rouge-score sqlitedict
# Installing collected packages: sqlitedict, tcolorpy, pybind11, portalocker, pathvalidate, mbstrdecoder, jsonlines, colorama, typepy, tqdm-multiprocess, sacrebleu, rouge-score, responses, DataProperty, tabledata, evaluate, pytablewriter, lm_eval
# Successfully installed DataProperty-1.0.1 colorama-0.4.6 evaluate-0.4.1 jsonlines-4.0.0 lm_eval-0.4.1 mbstrdecoder-1.1.3 pathvalidate-3.2.0 portalocker-2.8.2 pybind11-2.11.1 pytablewriter-1.2.0 responses-0.18.0 rouge-score-0.1.2 sacrebleu-2.4.0 sqlitedict-2.1.0 tabledata-1.3.3 tcolorpy-0.1.4 tqdm-multiprocess-0.0.11 typepy-1.3.2
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.42.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy->bitsandbytes) (1.25.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.37.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: auto-gptq in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: optimum in /usr/local/lib/python3.10/dist-packages (1.17.0)
# Requirement already satisfied: autoawq in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.27.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.17.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.1.99)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.25.2)
# Requirement already satisfied: rouge in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.0.1)
# Requirement already satisfied: gekko in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (1.0.6)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (2.1.0+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.4.2)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.37.2)
# Requirement already satisfied: peft>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (0.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from auto-gptq) (4.66.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from optimum) (15.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum) (1.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum) (23.2)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from optimum) (0.20.3)
# Requirement already satisfied: tokenizers>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.15.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from autoawq) (4.9.0)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from autoawq) (2.1.0)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.22.0)
# Requirement already satisfied: autoawq-kernels in /usr/local/lib/python3.10/dist-packages (from autoawq) (0.0.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->auto-gptq) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->auto-gptq) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (2023.12.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->auto-gptq) (3.20.3)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->optimum) (10.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->auto-gptq) (3.9.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->auto-gptq) (2023.4)

# %%
# !lm_eval --model hf --model_args pretrained=Qwen/Qwen1.5-7B --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 1 --batch_size 8 --output_path ./eval_harness/Qwen1.5-7B
# Out:
# 2024-02-17 13:08:18.355350: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-17 13:08:18.355400: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-17 13:08:18.356973: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-17 13:08:19.532343: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading builder script: 100% 5.67k/5.67k [00:00<00:00, 21.1MB/s]
# 2024-02-17:13:08:22,147 INFO     [__main__.py:200] Verbosity set to INFO
# 2024-02-17:13:08:22,148 INFO     [__init__.py:358] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-02-17:13:08:26,650 INFO     [__main__.py:276] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-02-17:13:08:26,651 INFO     [__main__.py:277] Loading selected tasks...
# 2024-02-17:13:08:26,651 INFO     [evaluator.py:95] Setting random seed to 0
# 2024-02-17:13:08:26,651 INFO     [evaluator.py:99] Setting numpy seed to 1234
# 2024-02-17:13:08:26,651 INFO     [evaluator.py:103] Setting torch manual seed to 1234
# 2024-02-17:13:08:26,684 INFO     [huggingface.py:161] Using device 'cuda:0'
# config.json: 100% 663/663 [00:00<00:00, 4.56MB/s]
# model.safetensors.index.json: 100% 31.7k/31.7k [00:00<00:00, 25.0MB/s]
# Downloading shards:   0% 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0% 0.00/3.99G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 10.5M/3.99G [00:00<00:40, 99.2MB/s]
# model-00001-of-00004.safetensors:   1% 31.5M/3.99G [00:00<00:24, 160MB/s]
# model-00001-of-00004.safetensors:   2% 62.9M/3.99G [00:00<00:20, 191MB/s]
# model-00001-of-00004.safetensors:   2% 94.4M/3.99G [00:00<00:19, 203MB/s]
# model-00001-of-00004.safetensors:   3% 126M/3.99G [00:00<00:18, 208MB/s]
# model-00001-of-00004.safetensors:   4% 157M/3.99G [00:00<00:18, 212MB/s]
# model-00001-of-00004.safetensors:   5% 189M/3.99G [00:00<00:17, 215MB/s]
# model-00001-of-00004.safetensors:   6% 220M/3.99G [00:01<00:17, 217MB/s]
# model-00001-of-00004.safetensors:   6% 252M/3.99G [00:01<00:17, 215MB/s]
# model-00001-of-00004.safetensors:   7% 283M/3.99G [00:01<00:17, 216MB/s]
# model-00001-of-00004.safetensors:   8% 315M/3.99G [00:01<00:16, 216MB/s]
# model-00001-of-00004.safetensors:   9% 346M/3.99G [00:01<00:16, 218MB/s]
# model-00001-of-00004.safetensors:   9% 377M/3.99G [00:01<00:16, 220MB/s]
# model-00001-of-00004.safetensors:  10% 409M/3.99G [00:01<00:16, 220MB/s]
# model-00001-of-00004.safetensors:  11% 440M/3.99G [00:02<00:16, 219MB/s]
# model-00001-of-00004.safetensors:  12% 472M/3.99G [00:02<00:16, 218MB/s]
# model-00001-of-00004.safetensors:  13% 503M/3.99G [00:02<00:16, 217MB/s]
# model-00001-of-00004.safetensors:  13% 535M/3.99G [00:02<00:15, 217MB/s]
# model-00001-of-00004.safetensors:  14% 566M/3.99G [00:02<00:15, 218MB/s]
# model-00001-of-00004.safetensors:  15% 598M/3.99G [00:02<00:15, 217MB/s]
# model-00001-of-00004.safetensors:  16% 629M/3.99G [00:02<00:15, 219MB/s]
# model-00001-of-00004.safetensors:  17% 661M/3.99G [00:03<00:15, 220MB/s]
# model-00001-of-00004.safetensors:  17% 692M/3.99G [00:03<00:15, 219MB/s]
# model-00001-of-00004.safetensors:  18% 724M/3.99G [00:03<00:14, 218MB/s]
# model-00001-of-00004.safetensors:  19% 755M/3.99G [00:03<00:14, 220MB/s]
# model-00001-of-00004.safetensors:  20% 786M/3.99G [00:03<00:14, 219MB/s]
# model-00001-of-00004.safetensors:  21% 818M/3.99G [00:03<00:14, 219MB/s]
# model-00001-of-00004.safetensors:  21% 849M/3.99G [00:03<00:14, 219MB/s]
# model-00001-of-00004.safetensors:  22% 881M/3.99G [00:04<00:14, 217MB/s]
# model-00001-of-00004.safetensors:  23% 912M/3.99G [00:04<00:14, 218MB/s]
# model-00001-of-00004.safetensors:  24% 944M/3.99G [00:04<00:14, 217MB/s]
# model-00001-of-00004.safetensors:  24% 975M/3.99G [00:04<00:13, 216MB/s]
# model-00001-of-00004.safetensors:  25% 1.01G/3.99G [00:04<00:13, 215MB/s]
# model-00001-of-00004.safetensors:  26% 1.04G/3.99G [00:04<00:13, 215MB/s]
# model-00001-of-00004.safetensors:  27% 1.07G/3.99G [00:04<00:13, 215MB/s]
# model-00001-of-00004.safetensors:  28% 1.10G/3.99G [00:05<00:13, 215MB/s]
# model-00001-of-00004.safetensors:  28% 1.13G/3.99G [00:05<00:13, 211MB/s]
# model-00001-of-00004.safetensors:  29% 1.16G/3.99G [00:05<00:13, 209MB/s]
# model-00001-of-00004.safetensors:  30% 1.20G/3.99G [00:05<00:13, 209MB/s]
# model-00001-of-00004.safetensors:  31% 1.23G/3.99G [00:05<00:13, 208MB/s]
# model-00001-of-00004.safetensors:  31% 1.25G/3.99G [00:05<00:13, 197MB/s]
# model-00001-of-00004.safetensors:  32% 1.27G/3.99G [00:05<00:14, 193MB/s]
# model-00001-of-00004.safetensors:  32% 1.29G/3.99G [00:06<00:13, 193MB/s]
# model-00001-of-00004.safetensors:  33% 1.31G/3.99G [00:06<00:16, 161MB/s]
# model-00001-of-00004.safetensors:  33% 1.33G/3.99G [00:06<00:15, 171MB/s]
# model-00001-of-00004.safetensors:  34% 1.36G/3.99G [00:06<00:14, 184MB/s]
# model-00001-of-00004.safetensors:  35% 1.38G/3.99G [00:06<00:13, 187MB/s]
# model-00001-of-00004.safetensors:  35% 1.42G/3.99G [00:06<00:13, 196MB/s]
# model-00001-of-00004.safetensors:  36% 1.45G/3.99G [00:06<00:12, 202MB/s]
# model-00001-of-00004.safetensors:  37% 1.48G/3.99G [00:07<00:12, 205MB/s]
# model-00001-of-00004.safetensors:  38% 1.51G/3.99G [00:07<00:11, 211MB/s]
# model-00001-of-00004.safetensors:  39% 1.54G/3.99G [00:07<00:11, 213MB/s]
# model-00001-of-00004.safetensors:  39% 1.57G/3.99G [00:07<00:11, 215MB/s]
# model-00001-of-00004.safetensors:  40% 1.60G/3.99G [00:07<00:10, 217MB/s]
# model-00001-of-00004.safetensors:  41% 1.64G/3.99G [00:07<00:10, 216MB/s]
# model-00001-of-00004.safetensors:  42% 1.67G/3.99G [00:07<00:10, 215MB/s]
# model-00001-of-00004.safetensors:  43% 1.70G/3.99G [00:08<00:10, 217MB/s]
# model-00001-of-00004.safetensors:  43% 1.73G/3.99G [00:08<00:10, 219MB/s]
# model-00001-of-00004.safetensors:  44% 1.76G/3.99G [00:08<00:10, 218MB/s]
# model-00001-of-00004.safetensors:  45% 1.79G/3.99G [00:08<00:10, 218MB/s]
# model-00001-of-00004.safetensors:  46% 1.82G/3.99G [00:08<00:09, 218MB/s]
# model-00001-of-00004.safetensors:  47% 1.86G/3.99G [00:08<00:09, 216MB/s]
# model-00001-of-00004.safetensors:  47% 1.89G/3.99G [00:08<00:09, 218MB/s]
# model-00001-of-00004.safetensors:  48% 1.92G/3.99G [00:09<00:09, 220MB/s]
# model-00001-of-00004.safetensors:  49% 1.95G/3.99G [00:09<00:09, 218MB/s]
# model-00001-of-00004.safetensors:  50% 1.98G/3.99G [00:09<00:09, 219MB/s]
# model-00001-of-00004.safetensors:  50% 2.01G/3.99G [00:09<00:09, 217MB/s]
# model-00001-of-00004.safetensors:  51% 2.04G/3.99G [00:09<00:09, 216MB/s]
# model-00001-of-00004.safetensors:  52% 2.08G/3.99G [00:09<00:08, 217MB/s]
# model-00001-of-00004.safetensors:  53% 2.11G/3.99G [00:09<00:08, 216MB/s]
# model-00001-of-00004.safetensors:  54% 2.14G/3.99G [00:10<00:08, 217MB/s]
# model-00001-of-00004.safetensors:  54% 2.17G/3.99G [00:10<00:08, 210MB/s]
# model-00001-of-00004.safetensors:  55% 2.20G/3.99G [00:10<00:08, 211MB/s]
# model-00001-of-00004.safetensors:  56% 2.23G/3.99G [00:10<00:08, 211MB/s]
# model-00001-of-00004.safetensors:  57% 2.26G/3.99G [00:10<00:08, 211MB/s]
# model-00001-of-00004.safetensors:  58% 2.30G/3.99G [00:10<00:08, 211MB/s]
# model-00001-of-00004.safetensors:  58% 2.33G/3.99G [00:11<00:07, 211MB/s]
# model-00001-of-00004.safetensors:  59% 2.36G/3.99G [00:11<00:07, 211MB/s]
# model-00001-of-00004.safetensors:  60% 2.39G/3.99G [00:11<00:07, 211MB/s]
# model-00001-of-00004.safetensors:  61% 2.42G/3.99G [00:11<00:07, 213MB/s]
# model-00001-of-00004.safetensors:  62% 2.45G/3.99G [00:11<00:07, 212MB/s]
# model-00001-of-00004.safetensors:  62% 2.49G/3.99G [00:11<00:06, 215MB/s]
# model-00001-of-00004.safetensors:  63% 2.52G/3.99G [00:11<00:06, 216MB/s]
# model-00001-of-00004.safetensors:  64% 2.55G/3.99G [00:12<00:06, 215MB/s]
# model-00001-of-00004.safetensors:  65% 2.58G/3.99G [00:12<00:06, 216MB/s]
# model-00001-of-00004.safetensors:  65% 2.61G/3.99G [00:12<00:06, 216MB/s]
# model-00001-of-00004.safetensors:  66% 2.64G/3.99G [00:12<00:06, 215MB/s]
# model-00001-of-00004.safetensors:  67% 2.67G/3.99G [00:12<00:06, 215MB/s]
# model-00001-of-00004.safetensors:  68% 2.71G/3.99G [00:12<00:05, 216MB/s]
# model-00001-of-00004.safetensors:  69% 2.74G/3.99G [00:12<00:05, 220MB/s]
# model-00001-of-00004.safetensors:  69% 2.77G/3.99G [00:13<00:05, 219MB/s]
# model-00001-of-00004.safetensors:  70% 2.80G/3.99G [00:13<00:05, 219MB/s]
# model-00001-of-00004.safetensors:  71% 2.83G/3.99G [00:13<00:05, 218MB/s]
# model-00001-of-00004.safetensors:  72% 2.86G/3.99G [00:13<00:05, 219MB/s]
# model-00001-of-00004.safetensors:  73% 2.89G/3.99G [00:13<00:05, 219MB/s]
# model-00001-of-00004.safetensors:  73% 2.93G/3.99G [00:13<00:05, 211MB/s]
# model-00001-of-00004.safetensors:  74% 2.96G/3.99G [00:13<00:04, 209MB/s]
# model-00001-of-00004.safetensors:  75% 2.98G/3.99G [00:14<00:05, 201MB/s]
# model-00001-of-00004.safetensors:  75% 3.00G/3.99G [00:14<00:04, 199MB/s]
# model-00001-of-00004.safetensors:  76% 3.02G/3.99G [00:14<00:04, 201MB/s]
# model-00001-of-00004.safetensors:  76% 3.04G/3.99G [00:14<00:04, 196MB/s]
# model-00001-of-00004.safetensors:  77% 3.06G/3.99G [00:14<00:04, 198MB/s]
# model-00001-of-00004.safetensors:  77% 3.08G/3.99G [00:14<00:04, 201MB/s]
# model-00001-of-00004.safetensors:  78% 3.10G/3.99G [00:14<00:04, 202MB/s]
# model-00001-of-00004.safetensors:  79% 3.14G/3.99G [00:14<00:04, 205MB/s]
# model-00001-of-00004.safetensors:  79% 3.16G/3.99G [00:14<00:04, 204MB/s]
# model-00001-of-00004.safetensors:  80% 3.18G/3.99G [00:15<00:03, 205MB/s]
# model-00001-of-00004.safetensors:  80% 3.20G/3.99G [00:15<00:03, 203MB/s]
# model-00001-of-00004.safetensors:  81% 3.22G/3.99G [00:15<00:03, 203MB/s]
# model-00001-of-00004.safetensors:  82% 3.25G/3.99G [00:15<00:03, 205MB/s]
# model-00001-of-00004.safetensors:  82% 3.27G/3.99G [00:15<00:03, 205MB/s]
# model-00001-of-00004.safetensors:  83% 3.29G/3.99G [00:15<00:03, 203MB/s]
# model-00001-of-00004.safetensors:  83% 3.31G/3.99G [00:15<00:03, 203MB/s]
# model-00001-of-00004.safetensors:  84% 3.33G/3.99G [00:15<00:03, 203MB/s]
# model-00001-of-00004.safetensors:  84% 3.36G/3.99G [00:15<00:03, 202MB/s]
# model-00001-of-00004.safetensors:  85% 3.38G/3.99G [00:16<00:03, 203MB/s]
# model-00001-of-00004.safetensors:  85% 3.40G/3.99G [00:16<00:02, 204MB/s]
# model-00001-of-00004.safetensors:  86% 3.42G/3.99G [00:16<00:02, 196MB/s]
# model-00001-of-00004.safetensors:  86% 3.44G/3.99G [00:16<00:02, 192MB/s]
# model-00001-of-00004.safetensors:  87% 3.46G/3.99G [00:16<00:02, 194MB/s]
# model-00001-of-00004.safetensors:  87% 3.48G/3.99G [00:16<00:04, 120MB/s]
# model-00001-of-00004.safetensors:  88% 3.51G/3.99G [00:16<00:03, 145MB/s]
# model-00001-of-00004.safetensors:  89% 3.54G/3.99G [00:17<00:02, 165MB/s]
# model-00001-of-00004.safetensors:  90% 3.58G/3.99G [00:17<00:02, 181MB/s]
# model-00001-of-00004.safetensors:  90% 3.61G/3.99G [00:17<00:01, 192MB/s]
# model-00001-of-00004.safetensors:  91% 3.64G/3.99G [00:17<00:01, 199MB/s]
# model-00001-of-00004.safetensors:  92% 3.66G/3.99G [00:17<00:01, 201MB/s]
# model-00001-of-00004.safetensors:  93% 3.69G/3.99G [00:17<00:01, 205MB/s]
# model-00001-of-00004.safetensors:  93% 3.72G/3.99G [00:17<00:01, 207MB/s]
# model-00001-of-00004.safetensors:  94% 3.75G/3.99G [00:18<00:01, 208MB/s]
# model-00001-of-00004.safetensors:  95% 3.79G/3.99G [00:18<00:00, 209MB/s]
# model-00001-of-00004.safetensors:  96% 3.82G/3.99G [00:18<00:00, 211MB/s]
# model-00001-of-00004.safetensors:  96% 3.85G/3.99G [00:18<00:00, 213MB/s]
# model-00001-of-00004.safetensors:  97% 3.88G/3.99G [00:18<00:00, 213MB/s]
# model-00001-of-00004.safetensors:  98% 3.91G/3.99G [00:18<00:00, 214MB/s]
# model-00001-of-00004.safetensors:  99% 3.94G/3.99G [00:18<00:00, 213MB/s]
# model-00001-of-00004.safetensors: 100% 3.99G/3.99G [00:19<00:00, 208MB/s]
# Downloading shards:  25% 1/4 [00:19<00:58, 19.45s/it]
# model-00002-of-00004.safetensors:   0% 0.00/3.96G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   1% 31.5M/3.96G [00:00<00:18, 214MB/s]
# model-00002-of-00004.safetensors:   2% 62.9M/3.96G [00:00<00:18, 214MB/s]
# model-00002-of-00004.safetensors:   2% 94.4M/3.96G [00:00<00:17, 215MB/s]
# model-00002-of-00004.safetensors:   3% 126M/3.96G [00:00<00:18, 209MB/s]
# model-00002-of-00004.safetensors:   4% 157M/3.96G [00:00<00:17, 212MB/s]
# model-00002-of-00004.safetensors:   5% 189M/3.96G [00:00<00:17, 214MB/s]
# model-00002-of-00004.safetensors:  83% 3.30G/3.96G [00:15<00:03, 216MB/s]
# model-00002-of-00004.safetensors:  84% 3.33G/3.96G [00:15<00:02, 216MB/s]
# model-00002-of-00004.safetensors:  85% 3.37G/3.96G [00:15<00:02, 216MB/s]
# model-00002-of-00004.safetensors:  86% 3.40G/3.96G [00:16<00:02, 215MB/s]
# model-00002-of-00004.safetensors:  87% 3.43G/3.96G [00:16<00:02, 214MB/s]
# model-00002-of-00004.safetensors:  87% 3.46G/3.96G [00:16<00:02, 214MB/s]
# model-00002-of-00004.safetensors:  88% 3.49G/3.96G [00:16<00:02, 215MB/s]
# model-00002-of-00004.safetensors:  89% 3.52G/3.96G [00:16<00:02, 215MB/s]
# model-00002-of-00004.safetensors:  90% 3.55G/3.96G [00:16<00:01, 215MB/s]
# model-00002-of-00004.safetensors:  91% 3.59G/3.96G [00:16<00:01, 214MB/s]
# model-00002-of-00004.safetensors:  91% 3.62G/3.96G [00:17<00:01, 214MB/s]
# model-00002-of-00004.safetensors:  92% 3.65G/3.96G [00:17<00:01, 210MB/s]
# model-00002-of-00004.safetensors:  93% 3.68G/3.96G [00:17<00:01, 207MB/s]
# model-00002-of-00004.safetensors:  94% 3.70G/3.96G [00:17<00:01, 203MB/s]
# model-00002-of-00004.safetensors:  94% 3.73G/3.96G [00:17<00:01, 202MB/s]
# model-00002-of-00004.safetensors:  95% 3.75G/3.96G [00:17<00:01, 203MB/s]
# model-00002-of-00004.safetensors:  96% 3.79G/3.96G [00:17<00:00, 208MB/s]
# model-00002-of-00004.safetensors:  96% 3.82G/3.96G [00:18<00:00, 211MB/s]
# model-00002-of-00004.safetensors:  97% 3.85G/3.96G [00:18<00:00, 214MB/s]
# model-00002-of-00004.safetensors:  98% 3.88G/3.96G [00:18<00:00, 215MB/s]
# model-00002-of-00004.safetensors:  99% 3.91G/3.96G [00:18<00:00, 216MB/s]
# model-00002-of-00004.safetensors: 100% 3.96G/3.96G [00:18<00:00, 212MB/s]
# Downloading shards:  50% 2/4 [00:38<00:38, 19.08s/it]
# model-00003-of-00004.safetensors:   0% 0.00/3.96G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 10.5M/3.96G [00:00<01:34, 41.6MB/s]
# model-00003-of-00004.safetensors:   1% 31.5M/3.96G [00:00<00:38, 102MB/s]
# model-00003-of-00004.safetensors:   2% 62.9M/3.96G [00:00<00:25, 153MB/s]
# model-00003-of-00004.safetensors:   2% 94.4M/3.96G [00:00<00:21, 177MB/s]
# model-00003-of-00004.safetensors:   3% 126M/3.96G [00:00<00:20, 190MB/s]
# model-00003-of-00004.safetensors:   4% 147M/3.96G [00:00<00:19, 193MB/s]
# model-00003-of-00004.safetensors:   5% 178M/3.96G [00:01<00:18, 203MB/s]
# model-00003-of-00004.safetensors:   5% 210M/3.96G [00:01<00:17, 209MB/s]
# model-00003-of-00004.safetensors:   6% 241M/3.96G [00:01<00:17, 209MB/s]
# model-00003-of-00004.safetensors:   7% 273M/3.96G [00:01<00:17, 211MB/s]
# model-00003-of-00004.safetensors:   8% 304M/3.96G [00:01<00:17, 214MB/s]
# model-00003-of-00004.safetensors:   8% 336M/3.96G [00:01<00:16, 214MB/s]
# model-00003-of-00004.safetensors:   9% 367M/3.96G [00:01<00:16, 217MB/s]
# model-00003-of-00004.safetensors:  10% 398M/3.96G [00:02<00:16, 217MB/s]
# model-00003-of-00004.safetensors:  11% 430M/3.96G [00:02<00:16, 213MB/s]
# model-00003-of-00004.safetensors:  12% 461M/3.96G [00:02<00:16, 216MB/s]
# model-00003-of-00004.safetensors:  12% 493M/3.96G [00:02<00:16, 208MB/s]
# model-00003-of-00004.safetensors:  13% 524M/3.96G [00:02<00:16, 211MB/s]
# model-00003-of-00004.safetensors:  14% 556M/3.96G [00:02<00:15, 213MB/s]
# model-00003-of-00004.safetensors:  15% 587M/3.96G [00:02<00:15, 214MB/s]
# model-00003-of-00004.safetensors:  16% 619M/3.96G [00:03<00:15, 213MB/s]
# model-00003-of-00004.safetensors:  16% 650M/3.96G [00:03<00:15, 213MB/s]
# model-00003-of-00004.safetensors:  17% 682M/3.96G [00:03<00:15, 215MB/s]
# model-00003-of-00004.safetensors:  18% 713M/3.96G [00:03<00:15, 215MB/s]
# model-00003-of-00004.safetensors:  19% 744M/3.96G [00:03<00:14, 218MB/s]
# model-00003-of-00004.safetensors:  20% 776M/3.96G [00:03<00:14, 216MB/s]
# model-00003-of-00004.safetensors:  20% 807M/3.96G [00:03<00:14, 217MB/s]
# model-00003-of-00004.safetensors:  21% 839M/3.96G [00:04<00:14, 216MB/s]
# model-00003-of-00004.safetensors:  22% 870M/3.96G [00:04<00:14, 217MB/s]
# model-00003-of-00004.safetensors:  23% 902M/3.96G [00:04<00:14, 218MB/s]
# model-00003-of-00004.safetensors:  24% 933M/3.96G [00:04<00:14, 216MB/s]
# model-00003-of-00004.safetensors:  24% 965M/3.96G [00:04<00:13, 216MB/s]
# model-00003-of-00004.safetensors:  25% 996M/3.96G [00:04<00:13, 214MB/s]
# model-00003-of-00004.safetensors:  26% 1.03G/3.96G [00:04<00:13, 213MB/s]
# model-00003-of-00004.safetensors:  27% 1.06G/3.96G [00:05<00:13, 215MB/s]
# model-00003-of-00004.safetensors:  28% 1.09G/3.96G [00:05<00:13, 218MB/s]
# model-00003-of-00004.safetensors:  28% 1.12G/3.96G [00:05<00:13, 215MB/s]
# model-00003-of-00004.safetensors:  29% 1.15G/3.96G [00:05<00:12, 218MB/s]
# model-00003-of-00004.safetensors:  30% 1.18G/3.96G [00:05<00:12, 219MB/s]
# model-00003-of-00004.safetensors:  31% 1.22G/3.96G [00:05<00:12, 213MB/s]
# model-00003-of-00004.safetensors:  32% 1.25G/3.96G [00:06<00:13, 205MB/s]
# model-00003-of-00004.safetensors:  32% 1.27G/3.96G [00:06<00:13, 205MB/s]
# model-00003-of-00004.safetensors:  33% 1.29G/3.96G [00:06<00:13, 203MB/s]
# model-00003-of-00004.safetensors:  33% 1.32G/3.96G [00:06<00:12, 204MB/s]
# model-00003-of-00004.safetensors:  34% 1.34G/3.96G [00:06<00:12, 204MB/s]
# model-00003-of-00004.safetensors:  34% 1.36G/3.96G [00:06<00:12, 201MB/s]
# model-00003-of-00004.safetensors:  35% 1.38G/3.96G [00:06<00:12, 202MB/s]
# model-00003-of-00004.safetensors:  36% 1.41G/3.96G [00:06<00:12, 204MB/s]
# model-00003-of-00004.safetensors:  36% 1.43G/3.96G [00:06<00:12, 203MB/s]
# model-00003-of-00004.safetensors:  37% 1.45G/3.96G [00:07<00:12, 204MB/s]
# model-00003-of-00004.safetensors:  37% 1.47G/3.96G [00:07<00:12, 202MB/s]
# model-00003-of-00004.safetensors:  38% 1.49G/3.96G [00:07<00:12, 201MB/s]
# model-00003-of-00004.safetensors:  38% 1.51G/3.96G [00:07<00:13, 188MB/s]
# model-00003-of-00004.safetensors:  39% 1.53G/3.96G [00:07<00:13, 185MB/s]
# model-00003-of-00004.safetensors:  39% 1.55G/3.96G [00:07<00:13, 184MB/s]
# model-00003-of-00004.safetensors:  40% 1.57G/3.96G [00:07<00:12, 191MB/s]
# model-00003-of-00004.safetensors:  41% 1.60G/3.96G [00:07<00:11, 197MB/s]
# model-00003-of-00004.safetensors:  41% 1.64G/3.96G [00:07<00:11, 200MB/s]
# model-00003-of-00004.safetensors:  42% 1.66G/3.96G [00:08<00:11, 193MB/s]
# model-00003-of-00004.safetensors:  42% 1.68G/3.96G [00:08<00:12, 190MB/s]
# model-00003-of-00004.safetensors:  43% 1.70G/3.96G [00:08<00:11, 190MB/s]
# model-00003-of-00004.safetensors:  43% 1.72G/3.96G [00:08<00:11, 190MB/s]
# model-00003-of-00004.safetensors:  44% 1.74G/3.96G [00:08<00:11, 194MB/s]
# model-00003-of-00004.safetensors:  45% 1.76G/3.96G [00:08<00:11, 198MB/s]
# model-00003-of-00004.safetensors:  45% 1.78G/3.96G [00:08<00:11, 196MB/s]
# model-00003-of-00004.safetensors:  46% 1.80G/3.96G [00:08<00:10, 199MB/s]
# model-00003-of-00004.safetensors:  46% 1.84G/3.96G [00:08<00:10, 205MB/s]
# model-00003-of-00004.safetensors:  47% 1.87G/3.96G [00:09<00:09, 210MB/s]
# model-00003-of-00004.safetensors:  48% 1.90G/3.96G [00:09<00:09, 215MB/s]
# model-00003-of-00004.safetensors:  49% 1.93G/3.96G [00:09<00:09, 213MB/s]
# model-00003-of-00004.safetensors:  50% 1.96G/3.96G [00:09<00:09, 216MB/s]
# model-00003-of-00004.safetensors:  50% 1.99G/3.96G [00:09<00:09, 216MB/s]
# model-00003-of-00004.safetensors:  51% 2.02G/3.96G [00:09<00:08, 216MB/s]
# model-00003-of-00004.safetensors:  52% 2.06G/3.96G [00:10<00:08, 215MB/s]
# model-00003-of-00004.safetensors:  53% 2.09G/3.96G [00:10<00:08, 213MB/s]
# model-00003-of-00004.safetensors:  54% 2.12G/3.96G [00:10<00:08, 213MB/s]
# model-00003-of-00004.safetensors:  54% 2.15G/3.96G [00:10<00:08, 213MB/s]
# model-00003-of-00004.safetensors:  55% 2.18G/3.96G [00:10<00:08, 214MB/s]
# model-00003-of-00004.safetensors:  56% 2.21G/3.96G [00:10<00:08, 214MB/s]
# model-00003-of-00004.safetensors:  83% 3.27G/3.96G [00:15<00:03, 213MB/s]
# model-00003-of-00004.safetensors:  83% 3.30G/3.96G [00:15<00:03, 212MB/s]
# model-00003-of-00004.safetensors:  84% 3.33G/3.96G [00:16<00:02, 212MB/s]
# model-00003-of-00004.safetensors:  85% 3.37G/3.96G [00:16<00:02, 213MB/s]
# model-00003-of-00004.safetensors:  86% 3.40G/3.96G [00:16<00:02, 213MB/s]
# model-00003-of-00004.safetensors:  87% 3.43G/3.96G [00:16<00:02, 215MB/s]
# model-00003-of-00004.safetensors:  87% 3.46G/3.96G [00:16<00:02, 210MB/s]
# model-00003-of-00004.safetensors:  88% 3.49G/3.96G [00:16<00:02, 214MB/s]
# model-00003-of-00004.safetensors:  89% 3.52G/3.96G [00:16<00:02, 214MB/s]
# model-00003-of-00004.safetensors:  90% 3.55G/3.96G [00:17<00:01, 216MB/s]
# model-00003-of-00004.safetensors:  91% 3.59G/3.96G [00:17<00:01, 216MB/s]
# model-00003-of-00004.safetensors:  91% 3.62G/3.96G [00:17<00:01, 217MB/s]
# model-00003-of-00004.safetensors:  92% 3.65G/3.96G [00:17<00:01, 216MB/s]
# model-00003-of-00004.safetensors:  93% 3.68G/3.96G [00:17<00:01, 216MB/s]
# model-00003-of-00004.safetensors:  94% 3.71G/3.96G [00:17<00:01, 214MB/s]
# model-00003-of-00004.safetensors:  95% 3.74G/3.96G [00:17<00:01, 211MB/s]
# model-00003-of-00004.safetensors:  95% 3.77G/3.96G [00:18<00:00, 209MB/s]
# model-00003-of-00004.safetensors:  96% 3.80G/3.96G [00:18<00:00, 207MB/s]
# model-00003-of-00004.safetensors:  96% 3.82G/3.96G [00:18<00:00, 204MB/s]
# model-00003-of-00004.safetensors:  97% 3.85G/3.96G [00:18<00:00, 205MB/s]
# model-00003-of-00004.safetensors:  98% 3.87G/3.96G [00:18<00:00, 205MB/s]
# model-00003-of-00004.safetensors:  98% 3.89G/3.96G [00:18<00:00, 203MB/s]
# model-00003-of-00004.safetensors:  99% 3.91G/3.96G [00:18<00:00, 200MB/s]
# model-00003-of-00004.safetensors:  99% 3.93G/3.96G [00:19<00:00, 127MB/s]
# model-00003-of-00004.safetensors: 100% 3.96G/3.96G [00:19<00:00, 206MB/s]
# Downloading shards:  75% 3/4 [00:57<00:19, 19.21s/it]
# model-00004-of-00004.safetensors:   0% 0.00/3.54G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   1% 31.5M/3.54G [00:00<00:15, 221MB/s]
# model-00004-of-00004.safetensors:   2% 62.9M/3.54G [00:00<00:15, 220MB/s]
# model-00004-of-00004.safetensors:   3% 94.4M/3.54G [00:00<00:16, 214MB/s]
# model-00004-of-00004.safetensors:   4% 126M/3.54G [00:00<00:15, 215MB/s]
# model-00004-of-00004.safetensors:   4% 157M/3.54G [00:00<00:15, 216MB/s]
# model-00004-of-00004.safetensors:   5% 189M/3.54G [00:00<00:15, 213MB/s]
# model-00004-of-00004.safetensors:   6% 220M/3.54G [00:01<00:15, 215MB/s]
# model-00004-of-00004.safetensors:   7% 252M/3.54G [00:01<00:15, 216MB/s]
# model-00004-of-00004.safetensors:  97% 3.43G/3.54G [00:16<00:00, 189MB/s]
# model-00004-of-00004.safetensors:  98% 3.46G/3.54G [00:16<00:00, 195MB/s]
# model-00004-of-00004.safetensors:  98% 3.48G/3.54G [00:16<00:00, 198MB/s]
# model-00004-of-00004.safetensors:  99% 3.51G/3.54G [00:16<00:00, 205MB/s]
# model-00004-of-00004.safetensors: 100% 3.54G/3.54G [00:16<00:00, 211MB/s]
# Downloading shards: 100% 4/4 [01:14<00:00, 18.63s/it]
# Loading checkpoint shards: 100% 4/4 [00:05<00:00,  1.37s/it]
# generation_config.json: 100% 138/138 [00:00<00:00, 958kB/s]
# tokenizer_config.json: 100% 1.16k/1.16k [00:00<00:00, 7.85MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 31.8MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 25.2MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 39.1MB/s]
# special_tokens_map.json: 100% 295/295 [00:00<00:00, 1.96MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-02-17:13:09:49,499 INFO     [evaluator.py:150] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# Downloading readme: 100% 9.00k/9.00k [00:00<00:00, 31.6MB/s]
# Downloading data: 100% 190k/190k [00:00<00:00, 915kB/s]
# Downloading data: 100% 204k/204k [00:00<00:00, 2.32MB/s]
# Downloading data: 100% 55.7k/55.7k [00:00<00:00, 694kB/s]
# Generating train split: 100% 1119/1119 [00:00<00:00, 200240.03 examples/s]
# Generating test split: 100% 1172/1172 [00:00<00:00, 361344.04 examples/s]
# Generating validation split: 100% 299/299 [00:00<00:00, 145927.03 examples/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1454: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 20.4MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 17.1MB/s]
# Downloading readme: 100% 6.84k/6.84k [00:00<00:00, 30.4MB/s]
# Downloading data: 47.5MB [00:00, 63.6MB/s]
# Downloading data: 11.8MB [00:00, 40.8MB/s]
# Downloading data: 12.2MB [00:00, 40.1MB/s]
# Generating train split: 100% 39905/39905 [00:04<00:00, 9417.71 examples/s]
# Generating test split: 100% 10003/10003 [00:01<00:00, 9701.00 examples/s]
# Generating validation split: 100% 10042/10042 [00:01<00:00, 9614.16 examples/s]
# Map: 100% 39905/39905 [00:05<00:00, 6708.09 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 5777.91 examples/s]
# Downloading data: 100% 2.06M/2.06M [00:00<00:00, 8.52MB/s]
# Downloading data: 100% 118k/118k [00:00<00:00, 1.92MB/s]
# Downloading data: 100% 85.9k/85.9k [00:00<00:00, 1.16MB/s]
# Generating train split: 100% 40398/40398 [00:00<00:00, 1824698.40 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 699578.55 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 635363.84 examples/s]
# 2024-02-17:13:10:22,955 WARNING  [evaluator.py:182] Overwriting default num_fewshot of winogrande from None to 1
# 2024-02-17:13:10:22,955 WARNING  [evaluator.py:182] Overwriting default num_fewshot of hellaswag from None to 1
# 2024-02-17:13:10:22,955 WARNING  [evaluator.py:182] Overwriting default num_fewshot of arc_challenge from None to 1
# 2024-02-17:13:10:22,956 INFO     [task.py:360] Building contexts for winogrande on rank 0...
# 2024-02-17:13:10:23,055 INFO     [task.py:360] Building contexts for hellaswag on rank 0...
# 2024-02-17:13:10:49,415 INFO     [task.py:360] Building contexts for arc_challenge on rank 0...
# 2024-02-17:13:10:54,795 INFO     [evaluator.py:369] Running loglikelihood requests
# 100% 47389/47389 [10:53<00:00, 72.51it/s]
# fatal: not a git repository (or any of the parent directories): .git
# hf (pretrained=Qwen/Qwen1.5-7B), gen_kwargs: (None), limit: None, num_fewshot: 1, batch_size: 8
# |    Tasks    |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|-----:|---|-----:|
# |winogrande   |      1|none  |     1|acc     |0.6756|±  |0.0132|
# |hellaswag    |      1|none  |     1|acc     |0.5781|±  |0.0049|
# |             |       |none  |     1|acc_norm|0.7712|±  |0.0042|
# |arc_challenge|      1|none  |     1|acc     |0.4846|±  |0.0146|
# |             |       |none  |     1|acc_norm|0.5154|±  |0.0146|

# %%
# !lm_eval --model hf --model_args pretrained=kaitchup/Qwen1.5-7B-gptq-4bit --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 1 --batch_size 8 --output_path ./eval_harness/Qwen1.5-7B-gptq-4bit
# Out:
# 2024-02-17 13:23:50.229429: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-17 13:23:50.229490: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-17 13:23:50.230842: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-17 13:23:51.401389: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-17:13:23:53,584 INFO     [__main__.py:200] Verbosity set to INFO
# 2024-02-17:13:23:53,584 INFO     [__init__.py:358] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-02-17:13:23:58,096 INFO     [__main__.py:276] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-02-17:13:23:58,097 INFO     [__main__.py:277] Loading selected tasks...
# 2024-02-17:13:23:58,097 INFO     [evaluator.py:95] Setting random seed to 0
# 2024-02-17:13:23:58,097 INFO     [evaluator.py:99] Setting numpy seed to 1234
# 2024-02-17:13:23:58,097 INFO     [evaluator.py:103] Setting torch manual seed to 1234
# 2024-02-17:13:23:58,133 INFO     [huggingface.py:161] Using device 'cuda:0'
# 2024-02-17:13:23:59,104 WARNING  [qlinear_cuda.py:18] CUDA extension not installed.
# 2024-02-17:13:23:59,105 WARNING  [qlinear_cuda_old.py:17] CUDA extension not installed.
# Loading checkpoint shards: 100% 2/2 [00:02<00:00,  1.40s/it]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-02-17:13:24:03,662 INFO     [evaluator.py:150] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1454: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2024-02-17:13:24:13,124 WARNING  [evaluator.py:182] Overwriting default num_fewshot of winogrande from None to 1
# 2024-02-17:13:24:13,124 WARNING  [evaluator.py:182] Overwriting default num_fewshot of hellaswag from None to 1
# 2024-02-17:13:24:13,124 WARNING  [evaluator.py:182] Overwriting default num_fewshot of arc_challenge from None to 1
# 2024-02-17:13:24:13,126 INFO     [task.py:360] Building contexts for winogrande on rank 0...
# 2024-02-17:13:24:13,224 INFO     [task.py:360] Building contexts for hellaswag on rank 0...
# 2024-02-17:13:24:39,846 INFO     [task.py:360] Building contexts for arc_challenge on rank 0...
# 2024-02-17:13:24:45,188 INFO     [evaluator.py:369] Running loglikelihood requests
# 100% 47389/47389 [24:50<00:00, 31.79it/s]
# fatal: not a git repository (or any of the parent directories): .git
# hf (pretrained=kaitchup/Qwen1.5-7B-gptq-4bit), gen_kwargs: (None), limit: None, num_fewshot: 1, batch_size: 8
# |    Tasks    |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|-----:|---|-----:|
# |winogrande   |      1|none  |     1|acc     |0.6803|±  |0.0131|
# |hellaswag    |      1|none  |     1|acc     |0.5611|±  |0.0050|
# |             |       |none  |     1|acc_norm|0.7549|±  |0.0043|
# |arc_challenge|      1|none  |     1|acc     |0.4608|±  |0.0146|
# |             |       |none  |     1|acc_norm|0.4923|±  |0.0146|

# %%
# !lm_eval --model hf --model_args pretrained=kaitchup/Qwen1.5-7B-awq-4bit --tasks winogrande,hellaswag,arc_challenge --device cuda:0 --num_fewshot 1 --batch_size 8 --output_path ./eval_harness/Qwen1.5-7B-awq-4bit
# Out:
# 2024-02-17 13:52:57.981846: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-17 13:52:57.981996: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-17 13:52:57.983808: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-17 13:52:59.147991: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-17:13:53:01,356 INFO     [__main__.py:200] Verbosity set to INFO
# 2024-02-17:13:53:01,356 INFO     [__init__.py:358] lm_eval.tasks.initialize_tasks() is deprecated and no longer necessary. It will be removed in v0.4.2 release. TaskManager will instead be used.
# 2024-02-17:13:53:05,848 INFO     [__main__.py:276] Selected Tasks: ['arc_challenge', 'hellaswag', 'winogrande']
# 2024-02-17:13:53:05,848 INFO     [__main__.py:277] Loading selected tasks...
# 2024-02-17:13:53:05,848 INFO     [evaluator.py:95] Setting random seed to 0
# 2024-02-17:13:53:05,848 INFO     [evaluator.py:99] Setting numpy seed to 1234
# 2024-02-17:13:53:05,849 INFO     [evaluator.py:103] Setting torch manual seed to 1234
# 2024-02-17:13:53:05,880 INFO     [huggingface.py:161] Using device 'cuda:0'
# Loading checkpoint shards: 100% 2/2 [00:02<00:00,  1.36s/it]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2024-02-17:13:53:11,005 INFO     [evaluator.py:150] get_task_dict has been updated to accept an optional argument, `task_manager`Read more here:https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/interface.md#external-library-usage
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1454: FutureWarning: The repository for hellaswag contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hellaswag
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2024-02-17:13:53:20,489 WARNING  [evaluator.py:182] Overwriting default num_fewshot of winogrande from None to 1
# 2024-02-17:13:53:20,489 WARNING  [evaluator.py:182] Overwriting default num_fewshot of hellaswag from None to 1
# 2024-02-17:13:53:20,490 WARNING  [evaluator.py:182] Overwriting default num_fewshot of arc_challenge from None to 1
# 2024-02-17:13:53:20,491 INFO     [task.py:360] Building contexts for winogrande on rank 0...
# 2024-02-17:13:53:20,590 INFO     [task.py:360] Building contexts for hellaswag on rank 0...
# 2024-02-17:13:53:47,518 INFO     [task.py:360] Building contexts for arc_challenge on rank 0...
# 2024-02-17:13:53:52,927 INFO     [evaluator.py:369] Running loglikelihood requests
# 100% 47389/47389 [37:59<00:00, 20.79it/s]
# fatal: not a git repository (or any of the parent directories): .git
# hf (pretrained=kaitchup/Qwen1.5-7B-awq-4bit), gen_kwargs: (None), limit: None, num_fewshot: 1, batch_size: 8
# |    Tasks    |Version|Filter|n-shot| Metric |Value |   |Stderr|
# |-------------|------:|------|-----:|--------|-----:|---|-----:|
# |winogrande   |      1|none  |     1|acc     |0.5564|±  |0.0140|
# |hellaswag    |      1|none  |     1|acc     |0.3881|±  |0.0049|
# |             |       |none  |     1|acc_norm|0.4978|±  |0.0050|
# |arc_challenge|      1|none  |     1|acc     |0.3131|±  |0.0136|
# |             |       |none  |     1|acc_norm|0.3456|±  |0.0139|
